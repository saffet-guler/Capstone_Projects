# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to ***"Demand Prediction Project"***. This is the third capstone project.
# As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# In this project, the goal is to predict the number of future bike shares given the historical data of London bike shares. So this case should be handled as a time series problem with ***Bidirectional LSTM***.
#
# In order to achieve this goal, you will make predictions with LSTM, unlike the machine learning algorithms you have applied before. Long short term memory (LSTM) is an artificial repetitive neural network architecture used in the field of deep learning. Unlike standard feed forward neural networks, LSTM has feedback links. It can process not only single data points but also entire data series.
#
# Before diving into the project, please take a look at the Determines and Tasks.
#
# - **NOTE:** This tutorial assumes that you already know the basics of coding in Python and are familiar with the theory behind LSTM.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
#
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.
#
# Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# In the Pre-Processing task after train test split and robust scaling, the challenge for you will be to divide the data into time steps and transform it into a three dimentional numpy array.
#
# Then in the model building task, build your model appropriate and compare the train and validation losses using a graph.
#
# When making prediction, you will need to do the inverse transform process to get a true error score. Otherwise, the results you get with scaled target variables may mislead you.
#
# Finally, Visualize how well your model's predictions match the actual values of the test data and also calculate error scores.
#
#
# - ***Note:*** *What you can do in this project is more than what is asked of you.*

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis
#
# - Check Missing Values and Outliers
# - Plot Breakdowns of Data
#
#     *i.  Plot bike shares over time*
#
#     *ii.  Plot bike shares by months*
#
#     *iii. Plot bike shares by hours*
#
#     *iv. Plot bike shares by day of week*
#
#     *v. Plot the distribution of bike shares on holidays by seasons*
#
#
# #### 2. Data Pre-Processing
#
# - Train - Test Split
# - Scaling
# - Define a Function for Creating Time Steps
#
# #### 3. Model Building with LSTM
#
# - Create, Compile and Fit Bidirectional LSTM Model
# - Plot Train and Validation Losses
#
# #### 4. Demand Prediction
#
# - Inverse Transform
# - Plot Prediction
# - Calculate Train and Test Error Scores

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. Exploratory Data Analysis
#
# - Firstly, focus data based on the timestamp. You can create various variables such as, hour, day of week, day of month etc.
# - You can check missing values and outliers.
# - Also you can plot breakdowns of data.

# %%
df = pd.read_csv('store_sharing.csv')

# %%
df.head()
# Out:
#              timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0  2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1  2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2  2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3  2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4  2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                 cnt            t1  ...    is_weekend        season
# count  17414.000000  17414.000000  ...  17414.000000  17414.000000
# mean    1143.101642     12.468091  ...      0.285403      1.492075
# std     1085.108068      5.571818  ...      0.451619      1.118911
# min        0.000000     -1.500000  ...      0.000000      0.000000
# 25%      257.000000      8.000000  ...      0.000000      0.000000
# 50%      844.000000     12.500000  ...      0.000000      1.000000
# 75%     1671.750000     16.000000  ...      1.000000      2.000000
# max     7860.000000     34.000000  ...      1.000000      3.000000
#
# [8 rows x 9 columns]

# %%
import datetime as dt

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
df['hour'] = df['timestamp'].dt.hour
df['day_of_month'] = df['timestamp'].dt.day
df['day_of_week'] = df['timestamp'].dt.dayofweek
df['month'] = df['timestamp'].dt.month
df['year'] = df['timestamp'].dt.year

# %%
df.head()
# Out:
#             timestamp  cnt   t1   t2  ...  day_of_month  day_of_week  month  year
# 0 2015-01-04 00:00:00  182  3.0  2.0  ...             4            6      1  2015
# 1 2015-01-04 01:00:00  138  3.0  2.5  ...             4            6      1  2015
# 2 2015-01-04 02:00:00  134  2.5  2.5  ...             4            6      1  2015
# 3 2015-01-04 03:00:00   72  2.0  2.0  ...             4            6      1  2015
# 4 2015-01-04 04:00:00   47  2.0  0.0  ...             4            6      1  2015
#
# [5 rows x 15 columns]

# %%
df = df.set_index('timestamp')

# %%
df.head(2)
# Out:
#                      cnt   t1   t2  ...  day_of_week  month  year
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...            6      1  2015
# 2015-01-04 01:00:00  138  3.0  2.5  ...            6      1  2015
#
# [2 rows x 14 columns]

# %% [markdown]
# ### Check Missing Values and Outliers

# %%
df.isnull().sum()
# Out:
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# hour            0
# day_of_month    0
# day_of_week     0
# month           0
# year            0
# dtype: int64

# %%
plt.figure(figsize = (10, 7))
sns.distplot(df['cnt'], hist = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df['t1'],data = df)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (10, 7))
sns.distplot(df['t1'], hist = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df['t2'],data = df)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (10, 7))
sns.distplot(df['t2'], hist = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df['hum'],data = df)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (10, 7))
sns.distplot(df['hum'], hist = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df['wind_speed'],data = df)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (10, 7))
sns.distplot(df['wind_speed'], hist = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df['weather_code'],data = df)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (10, 7))
sns.distplot(df['weather_code'], hist = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['weather_code'].value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %% [markdown]
# ### Plot Breakdowns of Data

# %% [markdown]
# ***i. Plot bike shares over time***

# %%
plt.figure(figsize=(20,7))
sns.lineplot(x='timestamp', y="cnt", data=df)
plt.grid();

# %% [markdown]
# ***ii. Plot bike shares by months***

# %%
df_by_month = df.resample('m').sum()

plt.figure(figsize=(20,7))
sns.lineplot(x=df_by_month.index, y="cnt", data=df_by_month)
plt.grid();

# %%
plt.figure(figsize=(15,5))
sns.barplot(x="month", y ="cnt", data=df)

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='month',y='cnt',hue='year',data=df)

# %%
df.groupby('month').agg({'cnt':'sum'}).sort_values('cnt',ascending=False)
# Out:
#            cnt
# month
# 7      2286214
# 8      2171265
# 6      1967130
# 5      1897348
# 9      1891097
# 10     1800752
# 4      1600427
# 11     1381191
# 3      1352461
# 12     1254746
# 1      1166837
# 2      1136504

# %%
df.groupby(['year','month']).agg({'cnt':'sum'})
# Out:
#                 cnt
# year month
# 2015 1       546639
#      2       543594
#      3       695934
#      4       831582
#      5       895413
#      6      1033252
#      7      1120687
#      8      1033951
#      9       892478
#      10      865046
#      11      677332
#      12      602838
# 2016 1       582518
#      2       592910
#      3       656527
#      4       768845
#      5      1001935
#      6       933878
#      7      1165527
#      8      1137314
#      9       998619
#      10      935706
#      11      703859
#      12      651908
# 2017 1        37680

# %% [markdown]
# ***iii. Plot bike shares by hours***
# - *whether it is a holiday or not*
# - *You may want to see seasonal breakdowns*

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='hour',y='cnt',data=df)

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='hour',y='cnt',hue='is_holiday',data=df)

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='hour',y='cnt',hue='is_weekend',data=df)

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='hour',y='cnt',hue='season',data=df)

# %%
plt.figure(figsize=(20,5))
sns.pointplot(data=df, x='hour', y='cnt', hue='season')
plt.grid();

# %% [markdown]
# ***iv. Plot bike shares by day of week***
# - *You may want to see seasonal breakdowns*

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='day_of_week',y='cnt',data=df)
plt.grid()

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='season',y='cnt',hue='day_of_week',data=df)
plt.grid()

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='day_of_week',y='cnt',hue='season',data=df)
plt.grid()

# %% [markdown]
# ***v. Plot the distribution of bike shares on holidays by seasons***

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='season',y='cnt',hue='is_holiday',data=df)
plt.grid()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 2. Data Pre-Processing

# %% [markdown]
# ### Train - Test Split
#
# Appropriately split the data for optimum training.

# %%
df = df.drop(['year'],axis=1)

# %% [markdown]
# ### Scaling

# %% [markdown]
# **Robust Scaling**
#
# It is common to scale data prior to fitting a machine learning model.
#
# This is because data often consists of many different input variables or features (columns) and each may have a different range of values or units of measure, such as feet, miles, kilograms, dollars, etc.
#
# If there are input variables that have very large values relative to the other input variables, these large values can dominate or skew some machine learning algorithms. The result is that the algorithms pay most of their attention to the large values and ignore the variables with smaller values.
#
# LSTMs are sensitive to the scale of the input data, specifically when the sigmoid (default) or tanh activation functions are used. It can be a good practice to rescale the data to the range of 0-to-1, also called normalizing. You can easily normalize the dataset using the Robust Scaling preprocessing class from the scikit-learn library.
#
# - ***Note:*** *You are expected to scale only 't1', 't2', 'hum', 'wind_speed' variables. You also need to scale the dependent and independent variables separately. You must do this for both train data and test data.*

# %%
from sklearn.preprocessing import RobustScaler

f_columns = ['t1','t2', 'hum', 'wind_speed']

f_transformer = RobustScaler()
cnt_transformer = RobustScaler()

f_transformer = f_transformer.fit(df[f_columns].to_numpy())
cnt_transformer = cnt_transformer.fit(df[['cnt']])

df.loc[:, f_columns] = f_transformer.transform(df[f_columns].to_numpy())
df['cnt'] = cnt_transformer.transform(df[['cnt']])

# %%
df.describe()
# Out:
#                 cnt            t1  ...  day_of_week         month
# count  17414.000000  17414.000000  ...  17414.00000  17414.000000
# mean       0.211417     -0.003989  ...      2.99265      6.514643
# std        0.766996      0.696477  ...      2.00406      3.452509
# min       -0.596572     -1.750000  ...      0.00000      1.000000
# 25%       -0.414914     -0.562500  ...      1.00000      4.000000
# 50%        0.000000      0.000000  ...      3.00000      7.000000
# 75%        0.585086      0.437500  ...      5.00000     10.000000
# max        4.959180      2.687500  ...      6.00000     12.000000
#
# [8 rows x 13 columns]

# %%
train_size = int(len(df) * 0.9)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(len(train), len(test))
# Out:
# 15672 1742

# %%
train.shape
# Out:
# (15672, 13)

# %%
test.shape
# Out:
# (1742, 13)

# %% [markdown]
# ### Define a Function for Creating Time Steps
#
# In order to use the capabilities of LSTM, we need to organize the data in accordance with the working principles of LSTM.
# You must separate the lines ordered by time in decimal steps.
# The size of the step may vary depending on the situation, in this case it is set to 10.
#
# Therefore, train and test data should be divided into groups of ten.
# When predicting test data, the model is asked to use the information from the next 10 records with itself for each record.
#
# As a result of this operation, each row will create a time step with the next 10 records, and you will have a matrix consisting of steps as many as the row total at the beginning.
# So, your data set must be a 3-dimensional numpy array like (15662, 10,13).
# As a result, LSTM will learn by taking 10 rows into account for one row.
#
# Create a function, that takes two arguments: the dataset(dependent or independent variables separately), which is a NumPy array that we want to convert into a dataset, and the time_steps, which is the number of previous time steps to use as input variables to predict the next time period.
#
# After defining the function, apply it to train and test sets.

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 10

# reshape to [samples, time_steps, n_features]

X_train, y_train = create_dataset(train, train.cnt,time_steps)
X_test, y_test = create_dataset(test, test.cnt,time_steps)

print(X_train.shape, y_train.shape)
# Out:
# (15662, 10, 13) (15662,)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 3. Model Building with LSTM

# %% [markdown]
# ##Recurrent Neural Networks
# RNN are a type of artifcial neural network designed to recognize patterns in sequences of data, such as text, genomes, handwriting, the spoken word, numerical times series data.
#
# Recurrent Neural Networks use backpropagation algorithm for training. Because of their internal memory, RNN’s are able to remember important things about the input they received, which enables them to be very precise in predicting what’s coming next.
#
# RNNs could be stacked up to deeper versions, which contain more than 1 layers of RNN. Because RNNs are especially computationally expensive to train, normally a deep RNN model contains no more than 3 layers of LSTM.
#
# Train a bidirectional long short term memory (LSTM) recurrent neural network (RNN) with this data, making use of the self-loop and forget gate of LSTM.
#
# LSTM sequential learning model was chosen because of its ability to process sequential data and memorize data of past time steps.
#
# LSTM is a different type of gated RNN which is capable of learning long-term dependencies LSTM is not affected by vanishing gradient or exploding gradient problem
# Using Bidirectional LSTMs, we feed the learning algorithm with the original data once from beginning to the end and once from end to beginning.
#
# #### Bidirectional LSTM :
# Bidirectional LSTMs are an extension of traditional LSTMs that can improve model performance on sequence classification problems.
#
# In problems where all timesteps of the input sequence are available, Bidirectional LSTMs train two instead of one LSTMs on the input sequence. The first on the input sequence as-is and the second on a reversed copy of the input sequence. This can provide additional context to the network and result in faster and even fuller learning on the problem. Figure shows the mechanism of Bidirectional LSTM.
#
#
#
#
#
#
# ![Unknown-2.png](data:image/png;base64,...)

# %% [markdown]
# ### Create, Compile and Fit Bidirectional LSTM Model
#
# - Create a Sequential Model,
# - Add Bidirectional layers,
# - Apply Regularization (Drop Out),
# - Compile the model.
#
# ***Note:*** *Define the optimizer as the efficient stochastic gradient descent algorithm ***adam***.* *This is a popular version of gradient descent because it automatically tunes itself and gives good results in a wide range of problems.*
#
# *In this case, use ***mean squared error*** as the loss argument. This loss is for a regression problems and is defined in Keras as mean_squared_error.
# Also use defined in Keras as ***accuracy*** as the metrics.*

# %%
X_train.shape[1]
# Out:
# 10

# %%
X_train.shape[2]
# Out:
# 13

# %% [markdown]
# ### Plot Train and Validation Losses

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential()
model.add(
  keras.layers.Bidirectional(
    keras.layers.LSTM(
      units=128, 
      input_shape=(X_train.shape[1], X_train.shape[2])
    )
  )
)
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(
    X_train, y_train, 
    epochs=200, 
    batch_size=32, 
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/200
# 441/441 [==============================] - 12s 19ms/step - loss: 0.4092 - val_loss: 0.1113
# Epoch 2/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0938 - val_loss: 0.0643
# Epoch 3/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0607 - val_loss: 0.0428
# Epoch 4/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0441 - val_loss: 0.0381
# Epoch 5/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0341 - val_loss: 0.0387
# Epoch 6/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0305 - val_loss: 0.0315
# Epoch 7/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0263 - val_loss: 0.0317
# Epoch 8/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0260 - val_loss: 0.0339
# Epoch 9/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0231 - val_loss: 0.0307
# Epoch 10/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0226 - val_loss: 0.0304
# Epoch 11/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0202 - val_loss: 0.0378
# Epoch 12/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0206 - val_loss: 0.0432
# Epoch 13/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0195 - val_loss: 0.0273
# Epoch 14/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0186 - val_loss: 0.0335
# Epoch 15/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0183 - val_loss: 0.0388
# Epoch 16/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0183 - val_loss: 0.0381
# Epoch 17/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0171 - val_loss: 0.0413
# Epoch 18/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0172 - val_loss: 0.0268
# Epoch 19/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0171 - val_loss: 0.0337
# Epoch 20/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0162 - val_loss: 0.0373
# Epoch 21/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0158 - val_loss: 0.0330
# Epoch 22/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0149 - val_loss: 0.0367
# Epoch 23/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0148 - val_loss: 0.0292
# Epoch 24/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0150 - val_loss: 0.0462
# Epoch 25/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0153 - val_loss: 0.0365
# Epoch 26/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0134 - val_loss: 0.0460
# Epoch 27/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0137 - val_loss: 0.0337
# Epoch 28/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0139 - val_loss: 0.0399
# Epoch 29/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0137 - val_loss: 0.0377
# Epoch 30/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0130 - val_loss: 0.0349
# Epoch 31/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0129 - val_loss: 0.0337
# Epoch 32/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0129 - val_loss: 0.0444
# Epoch 33/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0122 - val_loss: 0.0398
# Epoch 34/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0128 - val_loss: 0.0278
# Epoch 35/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0117 - val_loss: 0.0294
# Epoch 36/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0126 - val_loss: 0.0337
# Epoch 37/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0127 - val_loss: 0.0263
# Epoch 38/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0119 - val_loss: 0.0313
# Epoch 39/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0117 - val_loss: 0.0293
# Epoch 40/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0112 - val_loss: 0.0284
# Epoch 41/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0108 - val_loss: 0.0253
# Epoch 42/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0106 - val_loss: 0.0264
# Epoch 43/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0106 - val_loss: 0.0286
# Epoch 44/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0105 - val_loss: 0.0291
# Epoch 45/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0105 - val_loss: 0.0303
# Epoch 46/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0106 - val_loss: 0.0300
# Epoch 47/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0100 - val_loss: 0.0231
# Epoch 48/200
# 441/441 [==============================] - 7s 17ms/step - loss: 0.0101 - val_loss: 0.0257
# Epoch 49/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0107 - val_loss: 0.0335
# Epoch 50/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0100 - val_loss: 0.0252
# Epoch 51/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0098 - val_loss: 0.0260
# Epoch 52/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0104 - val_loss: 0.0273
# Epoch 53/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0100 - val_loss: 0.0355
# Epoch 54/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0090 - val_loss: 0.0256
# Epoch 55/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0091 - val_loss: 0.0239
# Epoch 56/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0100 - val_loss: 0.0266
# Epoch 57/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0098 - val_loss: 0.0319
# Epoch 58/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0099 - val_loss: 0.0249
# Epoch 59/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0091 - val_loss: 0.0249
# Epoch 60/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0094 - val_loss: 0.0276
# Epoch 61/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0090 - val_loss: 0.0297
# Epoch 62/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0089 - val_loss: 0.0247
# Epoch 63/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0087 - val_loss: 0.0214
# Epoch 64/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0089 - val_loss: 0.0225
# Epoch 65/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0087 - val_loss: 0.0213
# Epoch 66/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0092 - val_loss: 0.0311
# Epoch 67/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0090 - val_loss: 0.0228
# Epoch 68/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0220
# Epoch 69/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0288
# Epoch 70/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0081 - val_loss: 0.0242
# Epoch 71/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0270
# Epoch 72/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0085 - val_loss: 0.0267
# Epoch 73/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0257
# Epoch 74/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0227
# Epoch 75/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0089 - val_loss: 0.0263
# Epoch 76/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0089 - val_loss: 0.0249
# Epoch 77/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0087 - val_loss: 0.0285
# Epoch 78/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0081 - val_loss: 0.0201
# Epoch 79/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0085 - val_loss: 0.0223
# Epoch 80/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0081 - val_loss: 0.0224
# Epoch 81/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0072 - val_loss: 0.0218
# Epoch 82/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0082 - val_loss: 0.0198
# Epoch 83/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0080 - val_loss: 0.0297
# Epoch 84/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0074 - val_loss: 0.0241
# Epoch 85/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0078 - val_loss: 0.0208
# Epoch 86/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0075 - val_loss: 0.0211
# Epoch 87/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0069 - val_loss: 0.0252
# Epoch 88/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0071 - val_loss: 0.0218
# Epoch 89/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0074 - val_loss: 0.0214
# Epoch 90/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0074 - val_loss: 0.0263
# Epoch 91/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0070 - val_loss: 0.0285
# Epoch 92/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0071 - val_loss: 0.0285
# Epoch 93/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0077 - val_loss: 0.0274
# Epoch 94/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0074 - val_loss: 0.0317
# Epoch 95/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0073 - val_loss: 0.0258
# Epoch 96/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0064 - val_loss: 0.0311
# Epoch 97/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0075 - val_loss: 0.0337
# Epoch 98/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0069 - val_loss: 0.0241
# Epoch 99/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0068 - val_loss: 0.0238
# Epoch 100/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0067 - val_loss: 0.0230
# Epoch 101/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0069 - val_loss: 0.0353
# Epoch 102/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0071 - val_loss: 0.0310
# Epoch 103/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0069 - val_loss: 0.0292
# Epoch 104/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0063 - val_loss: 0.0282
# Epoch 105/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0064 - val_loss: 0.0359
# Epoch 106/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0072 - val_loss: 0.0330
# Epoch 107/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0077 - val_loss: 0.0246
# Epoch 108/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0066 - val_loss: 0.0233
# Epoch 109/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0067 - val_loss: 0.0288
# Epoch 110/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0062 - val_loss: 0.0288
# Epoch 111/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0061 - val_loss: 0.0354
# Epoch 112/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0063 - val_loss: 0.0342
# Epoch 113/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0064 - val_loss: 0.0317
# Epoch 114/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0063 - val_loss: 0.0270
# Epoch 115/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0068 - val_loss: 0.0310
# Epoch 116/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0064 - val_loss: 0.0354
# Epoch 117/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0064 - val_loss: 0.0329
# Epoch 118/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0059 - val_loss: 0.0297
# Epoch 119/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0338
# Epoch 120/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0286
# Epoch 121/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0061 - val_loss: 0.0387
# Epoch 122/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0057 - val_loss: 0.0280
# Epoch 123/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0312
# Epoch 124/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0058 - val_loss: 0.0291
# Epoch 125/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0060 - val_loss: 0.0390
# Epoch 126/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0056 - val_loss: 0.0324
# Epoch 127/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0054 - val_loss: 0.0388
# Epoch 128/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0062 - val_loss: 0.0308
# Epoch 129/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0063 - val_loss: 0.0321
# Epoch 130/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0063 - val_loss: 0.0309
# Epoch 131/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0061 - val_loss: 0.0297
# Epoch 132/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0266
# Epoch 133/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0061 - val_loss: 0.0334
# Epoch 134/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0062 - val_loss: 0.0278
# Epoch 135/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0057 - val_loss: 0.0279
# Epoch 136/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0314
# Epoch 137/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0057 - val_loss: 0.0286
# Epoch 138/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0055 - val_loss: 0.0289
# Epoch 139/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0332
# Epoch 140/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0061 - val_loss: 0.0271
# Epoch 141/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0272
# Epoch 142/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0055 - val_loss: 0.0369
# Epoch 143/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0055 - val_loss: 0.0308
# Epoch 144/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0318
# Epoch 145/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0054 - val_loss: 0.0285
# Epoch 146/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0053 - val_loss: 0.0339
# Epoch 147/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0324
# Epoch 148/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0277
# Epoch 149/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0051 - val_loss: 0.0328
# Epoch 150/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0050 - val_loss: 0.0291
# Epoch 151/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0319
# Epoch 152/200
# 441/441 [==============================] - 8s 17ms/step - loss: 0.0065 - val_loss: 0.0263
# Epoch 153/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0258
# Epoch 154/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0289
# Epoch 155/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0053 - val_loss: 0.0301
# Epoch 156/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0289
# Epoch 157/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0299
# Epoch 158/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0292
# Epoch 159/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0057 - val_loss: 0.0290
# Epoch 160/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0294
# Epoch 161/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0277
# Epoch 162/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0049 - val_loss: 0.0290
# Epoch 163/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0053 - val_loss: 0.0278
# Epoch 164/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0318
# Epoch 165/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0051 - val_loss: 0.0293
# Epoch 166/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0049 - val_loss: 0.0276
# Epoch 167/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0055 - val_loss: 0.0318
# Epoch 168/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0348
# Epoch 169/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0054 - val_loss: 0.0287
# Epoch 170/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0275
# Epoch 171/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0466
# Epoch 172/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0060 - val_loss: 0.0422
# Epoch 173/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0356
# Epoch 174/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0369
# Epoch 175/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0055 - val_loss: 0.0417
# Epoch 176/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0420
# Epoch 177/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0061 - val_loss: 0.0343
# Epoch 178/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0057 - val_loss: 0.0415
# Epoch 179/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0057 - val_loss: 0.0490
# Epoch 180/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0053 - val_loss: 0.0355
# Epoch 181/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0059 - val_loss: 0.0345
# Epoch 182/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0055 - val_loss: 0.0461
# Epoch 183/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0430
# Epoch 184/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0442
# Epoch 185/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0422
# Epoch 186/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0059 - val_loss: 0.0360
# Epoch 187/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0060 - val_loss: 0.0366
# Epoch 188/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0057 - val_loss: 0.0414
# Epoch 189/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0380
# Epoch 190/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0358
# Epoch 191/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0345
# Epoch 192/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0057 - val_loss: 0.0375
# Epoch 193/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0057 - val_loss: 0.0324
# Epoch 194/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0274
# Epoch 195/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0052 - val_loss: 0.0383
# Epoch 196/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0058 - val_loss: 0.0341
# Epoch 197/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0056 - val_loss: 0.0317
# Epoch 198/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0051 - val_loss: 0.0329
# Epoch 199/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0048 - val_loss: 0.0284
# Epoch 200/200
# 441/441 [==============================] - 8s 18ms/step - loss: 0.0049 - val_loss: 0.0370

# %%
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 4. Demand Predictions

# %% [markdown]
# At this stage, you will measure the prediction success of your model. So, you will need to compare the actual values of the test data with their predicted values.
#
# For this reason, you must inverse transform the y_pred variable predicted by the model with the target variables of the train and test data you have previously scaled.

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[ 0.5045857 ],
#        [ 0.07467245],
#        [-0.22759718],
#        ...,
#        [-0.31383026],
#        [-0.44925463],
#        [-0.5036968 ]], dtype=float32)

# %%
y_test
# Out:
# array([ 0.37603817,  0.03534193, -0.16186605, ..., -0.3583672 ,
#        -0.43823997, -0.49832126])

# %% [markdown]
# ### Inverse Transform

# %%
y_train_inv = cnt_transformer.inverse_transform(y_train.reshape(1, -1))
y_test_inv = cnt_transformer.inverse_transform(y_test.reshape(1, -1))
y_pred_inv = cnt_transformer.inverse_transform(y_pred)

# %%
y_test_inv
# Out:
# array([[ 0.37603817,  0.03534193, -0.16186605, ..., -0.3583672 ,
#         -0.43823997, -0.49832126]])

# %%
y_pred_inv
# Out:
# array([[ 0.5045857 ],
#        [ 0.07467245],
#        [-0.22759718],
#        ...,
#        [-0.31383026],
#        [-0.44925463],
#        [-0.5036968 ]], dtype=float32)

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(20,7))
plt.plot(np.arange(0, len(y_train)), y_train_inv.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv.flatten(), marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('Bike Count')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show();

# %%
y_test_inv.flatten().shape
# Out:
# (1732,)

# %%
y_test_inv.shape
# Out:
# (1, 1732)

# %%
plt.figure(figsize=(20,7))
plt.plot(y_test_inv.flatten(), marker='.', label="true")
plt.plot(y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('Bike Count')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show();

# %% [markdown]
# ### Calculate Train and Test Error Scores

# %%
new_test= df.iloc[train_size+10:len(df)] # We clipped the first ten rows of the test data frame because it doesn't match

# %%
new_test["actaul"]=y_test_inv.flatten()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_test["pred"] = y_pred_inv.flatten()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_test.head()
# Out:
#                           cnt      t1    t2  ...  month    actaul      pred
# timestamp                                    ...
# 2016-10-23 18:00:00  0.376038 -0.1250 -0.10  ...     10  0.376038  0.504586
# 2016-10-23 19:00:00  0.035342 -0.1875 -0.15  ...     10  0.035342  0.074672
# 2016-10-23 20:00:00 -0.161866 -0.1875 -0.15  ...     10 -0.161866 -0.227597
# 2016-10-23 21:00:00 -0.270012 -0.1875 -0.15  ...     10 -0.270012 -0.231573
# 2016-10-23 22:00:00 -0.256582 -0.2500 -0.30  ...     10 -0.256582 -0.340876
#
# [5 rows x 15 columns]

# %%
new_test[['actaul','pred']]
# Out:
#                        actaul      pred
# timestamp
# 2016-10-23 18:00:00  0.376038  0.504586
# 2016-10-23 19:00:00  0.035342  0.074672
# 2016-10-23 20:00:00 -0.161866 -0.227597
# 2016-10-23 21:00:00 -0.270012 -0.231573
# 2016-10-23 22:00:00 -0.256582 -0.340876
# ...                       ...       ...
# 2017-01-03 19:00:00  0.139954  0.281659
# 2017-01-03 20:00:00 -0.214172 -0.095990
# 2017-01-03 21:00:00 -0.358367 -0.313830
# 2017-01-03 22:00:00 -0.438240 -0.449255
# 2017-01-03 23:00:00 -0.498321 -0.503697
#
# [1732 rows x 2 columns]

# %%
plt.figure(figsize=(20,7))
plt.plot(new_test['actaul'],label='true')
plt.plot(new_test['pred'],label='prediction')
plt.legend()
plt.grid()
plt.show();

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
print('R2 Score: ', r2_score(y_test, y_pred))
print('MAE: ', mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score:  0.9413600374034437
# MAE:  0.11079693515098323
